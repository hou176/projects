# %%
from demo  import jdt_db
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
import time
from snapshot_selenium import snapshot
from sklearn.ensemble import RandomForestClassifier # RF库
from pyecharts.charts import Bar3D
from pyecharts.globals import CurrentConfig, NotebookType  
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

# %%
min_time_1 = "'2022-04-01 00:00:00'"
min_time_2 = "'2022-05-01 00:00:00'"
max_time_1 = "'2022-07-01 00:00:00'"
max_time_2 = "'2022-08-01 00:00:00'"

# %%
# 数据导入
rfm_up = "SELECT	user_id,	user_name,	created_at,	money ,user_upgrade_group   FROM	jdt_user_upgrade_log  WHERE  created_at >= " + min_time_2 + " AND created_at <" + max_time_2 
rfm_price ="   SELECT   a.user_id, b.truename,FROM_UNIXTIME( a.pay_time, '%Y-%m-%d  %H:%i:%s' ) AS 'time',a.pay_price,  b.group_id    FROM   	jdt_litejdtstore_order AS a   	LEFT JOIN jdt_user AS b ON a.user_id = b.id    WHERE   	FROM_UNIXTIME( a.pay_time, '%Y-%m-%d %H:%i:%s' ) >= " + min_time_2 + "    	AND FROM_UNIXTIME( a.pay_time, '%Y-%m-%d %H:%i:%s' ) < " + max_time_2  + "    GROUP BY   	order_no"
rfm_logo ="   SELECT   user_id,   count(user_id) as counts   FROM   jdt_user_logon_in   WHERE   created_at  >=" + min_time_2 + "     AND  created_at < " + max_time_2  + "       GROUP BY   user_id"

# %%
print(rfm_up)
print('*'* 60)
print(rfm_price)
print('*'* 60)
print(rfm_logo)
# Out:
# SELECT	user_id,	user_name,	created_at,	money ,user_upgrade_group   FROM	jdt_user_upgrade_log  WHERE  created_at >= '2022-05-01 00:00:00' AND created_at <'2022-08-01 00:00:00'
# ************************************************************
#    SELECT   a.user_id, b.truename,FROM_UNIXTIME( a.pay_time, '%Y-%m-%d  %H:%i:%s' ) AS 'time',a.pay_price,  b.group_id    FROM   	jdt_litejdtstore_order AS a   	LEFT JOIN jdt_user AS b ON a.user_id = b.id    WHERE   	FROM_UNIXTIME( a.pay_time, '%Y-%m-%d %H:%i:%s' ) >= '2022-05-01 00:00:00'    	AND FROM_UNIXTIME( a.pay_time, '%Y-%m-%d %H:%i:%s' ) < '2022-08-01 00:00:00'    GROUP BY   	order_no
# ************************************************************
#    SELECT   user_id,   count(user_id) as counts   FROM   jdt_user_logon_in   WHERE   created_at  >='2022-05-01 00:00:00'     AND  created_at < '2022-08-01 00:00:00'       GROUP BY   user_id

# %%
# 升学人数
data1 = jdt_db(rfm_up)
# 商品购买
data2 = jdt_db(rfm_price)
# 登录频次
data3 = jdt_db(rfm_logo)
# Out:
# D:\anaconda\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# 0.9890966415405273
# D:\anaconda\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# 0.3295419216156006
# D:\anaconda\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# 11.517262697219849

# %%
data2 = data2.rename(columns={'truename':'user_name','time':'created_at','pay_price':'money','group_id':'user_upgrade_group'})

# %%
total_data = pd.concat([data1,data2],axis = 0)

# %%
total_data
# Out:
#       user_id    user_name            created_at   money  user_upgrade_group
# 0     1927744          张矜斓   2022-05-01 07:55:03   199.0                   2
# 1     1927744          张矜斓   2022-05-01 08:08:11  4999.0                   3
# 2     1927663  18980361458   2022-05-01 09:05:07   499.0                   2
# 3     2060881          叶德新   2022-05-01 09:08:32   499.0                   2
# 4     2049494  18780927768   2022-05-01 09:12:08   199.0                   2
# ...       ...          ...                   ...     ...                 ...
# 1189  1638548          谢燕青  2022-07-24  17:53:25    30.0                   3
# 1190  1752688          陈秀丽  2022-07-24  18:00:39    30.0                   3
# 1191   103226          李艳平  2022-07-24  18:06:31    27.1                   5
# 1192  1948453          郭碧霞  2022-07-24  23:46:55    30.0                   4
# 1193   103226          李艳平  2022-07-26  10:18:14     5.5                   5
#
# [24728 rows x 5 columns]

# %%
total_data =pd.merge(total_data,data3,on='user_id',how = 'left')

# %%
total_data
# Out:
#        user_id    user_name            created_at   money  user_upgrade_group  \
# 0      1927744          张矜斓   2022-05-01 07:55:03   199.0                   2
# 1      1927744          张矜斓   2022-05-01 08:08:11  4999.0                   3
# 2      1927663  18980361458   2022-05-01 09:05:07   499.0                   2
# 3      2060881          叶德新   2022-05-01 09:08:32   499.0                   2
# 4      2049494  18780927768   2022-05-01 09:12:08   199.0                   2
# ...        ...          ...                   ...     ...                 ...
# 24723  1638548          谢燕青  2022-07-24  17:53:25    30.0                   3
# 24724  1752688          陈秀丽  2022-07-24  18:00:39    30.0                   3
# 24725   103226          李艳平  2022-07-24  18:06:31    27.1                   5
# 24726  1948453          郭碧霞  2022-07-24  23:46:55    30.0                   4
# 24727   103226          李艳平  2022-07-26  10:18:14     5.5                   5
#
#        counts
# 0        10.0
# 1        10.0
# 2         2.0
# 3         2.0
# 4         6.0
# ...       ...
# 24723    27.0
# 24724     9.0
# 24725    13.0
# 24726     9.0
# 24727    13.0
#
# [24728 rows x 6 columns]

# %%
total_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24728 entries, 0 to 24727
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             24728 non-null  int64
#  1   user_name           24728 non-null  object
#  2   created_at          24728 non-null  object
#  3   money               24728 non-null  float64
#  4   user_upgrade_group  24728 non-null  int64
#  5   counts              24667 non-null  float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.3+ MB

# %%
total_data['created_at'] = pd.to_datetime(total_data['created_at'])

# %%
total_data['max_time'] = pd.to_datetime(datetime.datetime.now() )

# %%
total_data = total_data[total_data['user_upgrade_group'] < 4]

# %%
total_data = total_data[total_data['money'] > 0]

# %%
total_data['date_interval'] = total_data['max_time'] - total_data['created_at']

# %%
total_data['month'] = total_data['created_at'].dt.month

# %%
total_data['date_interval'] = total_data['date_interval'].apply(lambda x: x.days)

# %%
total_data
# Out:
#        user_id    user_name          created_at   money  user_upgrade_group  \
# 0      1927744          张矜斓 2022-05-01 07:55:03   199.0                   2
# 1      1927744          张矜斓 2022-05-01 08:08:11  4999.0                   3
# 2      1927663  18980361458 2022-05-01 09:05:07   499.0                   2
# 3      2060881          叶德新 2022-05-01 09:08:32   499.0                   2
# 4      2049494  18780927768 2022-05-01 09:12:08   199.0                   2
# ...        ...          ...                 ...     ...                 ...
# 24716  1708375          王秀清 2022-07-22 20:29:17    30.0                   3
# 24719   150061          李海鹏 2022-07-23 14:39:40    30.0                   3
# 24721  1718776          苏雪贞 2022-07-24 09:30:31    30.0                   3
# 24723  1638548          谢燕青 2022-07-24 17:53:25    30.0                   3
# 24724  1752688          陈秀丽 2022-07-24 18:00:39    30.0                   3
#
#        counts                   max_time  date_interval  month
# 0        10.0 2022-07-26 10:45:46.375764             86      5
# 1        10.0 2022-07-26 10:45:46.375764             86      5
# 2         2.0 2022-07-26 10:45:46.375764             86      5
# 3         2.0 2022-07-26 10:45:46.375764             86      5
# 4         6.0 2022-07-26 10:45:46.375764             86      5
# ...       ...                        ...            ...    ...
# 24716    10.0 2022-07-26 10:45:46.375764              3      7
# 24719    10.0 2022-07-26 10:45:46.375764              2      7
# 24721    13.0 2022-07-26 10:45:46.375764              2      7
# 24723    27.0 2022-07-26 10:45:46.375764              1      7
# 24724     9.0 2022-07-26 10:45:46.375764              1      7
#
# [21619 rows x 9 columns]

# %%
rfm_gb = total_data.groupby(['month','user_id'],as_index=False).agg(
    {'date_interval': 'min',  # 计算最近一次订单时间
     'counts': 'max', # 计算订单频率
     'money': 'sum',
    'user_upgrade_group':'max'})  # 计算订单总金额

# %%
rfm_gb_group = rfm_gb[rfm_gb['user_upgrade_group']<4]

# %%
rfm_gb_group
# Out:
#        month  user_id  date_interval  counts    money  user_upgrade_group
# 0          5     1570             65     6.0   499.00                   2
# 1          5     4209             62     2.0   499.00                   2
# 2          5     7238             81     3.0  4999.00                   3
# 3          5     7586             70    16.0  4999.00                   3
# 4          5     8680             80    13.0    49.69                   2
# ...      ...      ...            ...     ...      ...                 ...
# 18246      7  2194819              0     3.0   499.00                   2
# 18247      7  2195014              0     2.0   199.00                   2
# 18248      7  2195220              0     2.0  5198.00                   3
# 18249      7  2195275              0     1.0   499.00                   2
# 18250      7  2195301              0     2.0   199.00                   2
#
# [18251 rows x 6 columns]

# %%
rfm_gb.columns =  ['month','user_id','r','f','m','user_group']
rfm_gb
# Out:
#        month  user_id   r     f        m  user_group
# 0          5     1570  65   6.0   499.00           2
# 1          5     4209  62   2.0   499.00           2
# 2          5     7238  81   3.0  4999.00           3
# 3          5     7586  70  16.0  4999.00           3
# 4          5     8680  80  13.0    49.69           2
# ...      ...      ...  ..   ...      ...         ...
# 18246      7  2194819   0   3.0   499.00           2
# 18247      7  2195014   0   2.0   199.00           2
# 18248      7  2195220   0   2.0  5198.00           3
# 18249      7  2195275   0   1.0   499.00           2
# 18250      7  2195301   0   2.0   199.00           2
#
# [18251 rows x 6 columns]

# %%
desc_pd = rfm_gb.iloc[:,2:].describe().T
desc_pd
# Out:
#               count         mean          std  min    25%    50%     75%  \
# r           18251.0    45.714810    25.554787  0.0   24.0   45.0    70.0
# f           18200.0     6.302033     5.953262  1.0    3.0    5.0     8.0
# m           18251.0  1970.512810  2299.756707  5.5  199.0  499.0  4999.0
# user_group  18251.0     2.343269     0.479407  1.0    2.0    2.0     3.0
#
#                 max
# r              86.0
# f             118.0
# m           10197.0
# user_group      3.0

# %%
r_bins = [-1,24,70,86] # 注意起始边界小于最小值
f_bins = [0,3,8,118] 
m_bins = [5,199,4999,10197]

# %%
# rfm_merge = pd.merge(rfm_gb,total_data,on='user_id',how='inner')

# %%
rfm_merge = rfm_gb

# %%
rfm_merge.isnull().any()
# Out:
# month         False
# user_id       False
# r             False
# f              True
# m             False
# user_group    False
# dtype: bool

# %%
rfm_merge['f'] = rfm_merge['f'].fillna(1)

# %%
# 计算权重因子
clf = RandomForestClassifier()
clf = clf.fit(rfm_merge[['r','f','m']],rfm_merge['user_group'])
weights = clf.feature_importances_
print('feature importance:',weights)
# Out:
# feature importance: [0.04935235 0.11107823 0.83956942]

# %%
rfm_gb
# Out:
#        month  user_id   r     f        m  user_group
# 0          5     1570  65   6.0   499.00           2
# 1          5     4209  62   2.0   499.00           2
# 2          5     7238  81   3.0  4999.00           3
# 3          5     7586  70  16.0  4999.00           3
# 4          5     8680  80  13.0    49.69           2
# ...      ...      ...  ..   ...      ...         ...
# 18246      7  2194819   0   3.0   499.00           2
# 18247      7  2195014   0   2.0   199.00           2
# 18248      7  2195220   0   2.0  5198.00           3
# 18249      7  2195275   0   1.0   499.00           2
# 18250      7  2195301   0   2.0   199.00           2
#
# [18251 rows x 6 columns]

# %%
# 计算分箱得分
rfm_gb['r_score'] = pd.cut(rfm_gb['r'], r_bins, labels=[i for i in range(len(r_bins)-1,0,-1)])  

rfm_gb['m_score'] = pd.cut(rfm_gb['m'], m_bins, labels=[i+1 for i in range(len(m_bins)-1)])  

rfm_gb['f_score'] = pd.cut(rfm_gb['f'], f_bins, labels=[i+1 for i in range(len(f_bins)-1)])

# %%
rfm_gb
# Out:
#        month  user_id   r     f        m  user_group r_score m_score f_score
# 0          5     1570  65   6.0   499.00           2       2       2       2
# 1          5     4209  62   2.0   499.00           2       2       2       1
# 2          5     7238  81   3.0  4999.00           3       1       2       1
# 3          5     7586  70  16.0  4999.00           3       2       2       3
# 4          5     8680  80  13.0    49.69           2       1       1       3
# ...      ...      ...  ..   ...      ...         ...     ...     ...     ...
# 18246      7  2194819   0   3.0   499.00           2       3       2       1
# 18247      7  2195014   0   2.0   199.00           2       3       1       1
# 18248      7  2195220   0   2.0  5198.00           3       3       3       1
# 18249      7  2195275   0   1.0   499.00           2       3       2       1
# 18250      7  2195301   0   2.0   199.00           2       3       1       1
#
# [18251 rows x 9 columns]

# %%
rfm_gb.drop_duplicates(subset='m_score',inplace=False)
# Out:
#     month  user_id   r     f        m  user_group r_score m_score f_score
# 0       5     1570  65   6.0   499.00           2       2       2       2
# 4       5     8680  80  13.0    49.69           2       1       1       3
# 18      5    38162  57  58.0  5498.00           3       2       3       3

# %%
rfm_gb = rfm_gb.apply(np.int32) 
rfm_gb['rfm_score'] = rfm_gb['r_score'] * weights[0] + rfm_gb['f_score'] * weights[1] + rfm_gb['m_score'] * weights[2]

# %%
rfm_gb
# Out:
#        month  user_id   r   f     m  user_group  r_score  m_score  f_score  \
# 0          5     1570  65   6   499           2        2        2        2
# 1          5     4209  62   2   499           2        2        2        1
# 2          5     7238  81   3  4999           3        1        2        1
# 3          5     7586  70  16  4999           3        2        2        3
# 4          5     8680  80  13    49           2        1        1        3
# ...      ...      ...  ..  ..   ...         ...      ...      ...      ...
# 18246      7  2194819   0   3   499           2        3        2        1
# 18247      7  2195014   0   2   199           2        3        1        1
# 18248      7  2195220   0   2  5198           3        3        3        1
# 18249      7  2195275   0   1   499           2        3        2        1
# 18250      7  2195301   0   2   199           2        3        1        1
#
#        rfm_score
# 0       2.000000
# 1       1.888922
# 2       1.839569
# 3       2.111078
# 4       1.222156
# ...          ...
# 18246   1.938274
# 18247   1.098705
# 18248   2.777844
# 18249   1.938274
# 18250   1.098705
#
# [18251 rows x 10 columns]

# %%
rfm_gb['r_score'] = rfm_gb['r_score'].astype(np.str)
rfm_gb['f_score'] = rfm_gb['f_score'].astype(np.str)
rfm_gb['m_score'] = rfm_gb['m_score'].astype(np.str)
rfm_gb['rfm_group'] = rfm_gb['r_score'].str.cat(rfm_gb['f_score']).str.cat(rfm_gb['m_score'])
# Out:
# C:\Users\cy176\AppData\Local\Temp\ipykernel_19892\2199335445.py:1: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   rfm_gb['r_score'] = rfm_gb['r_score'].astype(np.str)
# C:\Users\cy176\AppData\Local\Temp\ipykernel_19892\2199335445.py:2: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   rfm_gb['f_score'] = rfm_gb['f_score'].astype(np.str)
# C:\Users\cy176\AppData\Local\Temp\ipykernel_19892\2199335445.py:3: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   rfm_gb['m_score'] = rfm_gb['m_score'].astype(np.str)

# %%
rfm_gb
# Out:
#        month  user_id   r   f     m  user_group r_score m_score f_score  \
# 0          5     1570  65   6   499           2       2       2       2
# 1          5     4209  62   2   499           2       2       2       1
# 2          5     7238  81   3  4999           3       1       2       1
# 3          5     7586  70  16  4999           3       2       2       3
# 4          5     8680  80  13    49           2       1       1       3
# ...      ...      ...  ..  ..   ...         ...     ...     ...     ...
# 18246      7  2194819   0   3   499           2       3       2       1
# 18247      7  2195014   0   2   199           2       3       1       1
# 18248      7  2195220   0   2  5198           3       3       3       1
# 18249      7  2195275   0   1   499           2       3       2       1
# 18250      7  2195301   0   2   199           2       3       1       1
#
#        rfm_score rfm_group
# 0       2.000000       222
# 1       1.888922       212
# 2       1.839569       112
# 3       2.111078       232
# 4       1.222156       131
# ...          ...       ...
# 18246   1.938274       312
# 18247   1.098705       311
# 18248   2.777844       313
# 18249   1.938274       312
# 18250   1.098705       311
#
# [18251 rows x 11 columns]

# %%
total_data = total_data[['user_id','user_name']]

# %%
total_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21619 entries, 0 to 24724
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user_id    21619 non-null  int64
#  1   user_name  21619 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 506.7+ KB

# %%
rfm_gb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18251 entries, 0 to 18250
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   month       18251 non-null  int32
#  1   user_id     18251 non-null  int32
#  2   r           18251 non-null  int32
#  3   f           18251 non-null  int32
#  4   m           18251 non-null  int32
#  5   user_group  18251 non-null  int32
#  6   r_score     18251 non-null  object
#  7   m_score     18251 non-null  object
#  8   f_score     18251 non-null  object
#  9   rfm_score   18251 non-null  float64
#  10  rfm_group   18251 non-null  object
# dtypes: float64(1), int32(6), object(4)
# memory usage: 1.1+ MB

# %%
rfm_gb_ = pd.merge(rfm_gb,total_data,on='user_id',how = 'left')
rfm_gb_ = rfm_gb_.drop_duplicates(subset='user_id',inplace=False)

# %%
rfm_gb_ = rfm_gb_[['user_id','user_name','user_group','r_score','f_score','m_score','rfm_group','rfm_score']]
rfm_gb_
# Out:
#        user_id    user_name  user_group r_score f_score m_score rfm_group  \
# 0         1570           琼英           2       2       2       2       222
# 1         4209          朱利琴           2       2       1       2       212
# 2         7238          舒开菊           3       1       1       2       112
# 3         7586          宋晓梅           3       2       3       2       232
# 4         8680           陈彤           2       1       3       1       131
# ...        ...          ...         ...     ...     ...     ...       ...
# 23069  2194819          张秀芳           2       3       1       2       312
# 23070  2195014          章培清           2       3       1       1       311
# 23071  2195220          施文华           3       3       1       3       313
# 23073  2195275  13330317863           2       3       1       2       312
# 23074  2195301          朱海彬           2       3       1       1       311
#
#        rfm_score
# 0       2.000000
# 1       1.888922
# 2       1.839569
# 3       2.111078
# 4       1.222156
# ...          ...
# 23069   1.938274
# 23070   1.098705
# 23071   2.777844
# 23073   1.938274
# 23074   1.098705
#
# [17527 rows x 8 columns]

# %%
display_data = rfm_gb.groupby(['rfm_group','month'],as_index=False)['user_id'].count()
display_data.columns = ['rfm_group','month','number']
display_data['rfm_group'] = display_data['rfm_group'].astype(np.int32)
# Out:
#    rfm_group  month  number
# 0        111      5     483
# 1        112      5     588
# 2        113      5      43
# 3        121      5     991
# 4        122      5     848

# %%
rfm_user_id_list = list(rfm_gb['user_id'])

# %%
rfm_user_id_str = ' ,'.join('%s' %id for id in rfm_user_id_list)

# %%
import random
import pyecharts.options as opts
from pyecharts.charts import Bar3D

data = display_data.values.tolist() 


c=(
    Bar3D(init_opts=opts.InitOpts(width="900px", height="600px"))
    .add(
        series_name="",
        data=data,
        xaxis3d_opts=opts.Axis3DOpts(type_="category",data = display_data['rfm_group']),
        yaxis3d_opts=opts.Axis3DOpts(type_="category", data = display_data['month']),
        zaxis3d_opts=opts.Axis3DOpts(type_="value"),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts("健康帮RFM价值分层柱状3D图"),
        visualmap_opts=opts.VisualMapOpts(
            max_=1300,
            range_color=[
                "#313695",
                "#4575b4",
                "#74add1",
                "#abd9e9",
                "#e0f3f8",
                "#ffffbf",
                "#fee090",
                "#fdae61",
                "#f46d43",
                "#d73027",
                "#a50026",
            ],
        )
    )
)
c.load_javascript()

# %%
make_snapshot(snapshot,c.render(),'1.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [241], in <cell line: 1>()
# ----> 1 make_snapshot(snapshot,c.render(),'1.png')
#
# NameError: name 'make_snapshot' is not defined

# %%
c.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="a6f8d4ab58b74edc8d8a3fb1240f186c" class="chart-container" style="width:900px; height:600px;"></div>
#     <script>
#         var chart_a6f8d4ab58b74edc8d8a3fb1240f186c = echarts.init(
#             document.getElementById('a6f8d4ab58b74edc8d8a3fb1240f186c'), 'white', {renderer: 'canvas'});
#         var option_a6f8d4ab58b74edc8d8a3fb1240f186c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar3D",
#             "data": [
#                 [
#                     111,
#                     5,
#                     483
#                 ],
#                 [
#                     112,
#                     5,
#                     588
#                 ],
#                 [
#                     113,
#                     5,
#                     43
#                 ],
#                 [
#                     121,
#                     5,
#                     991
#                 ],
#                 [
#                     122,
#                     5,
#                     848
#                 ],
#                 [
#                     123,
#                     5,
#                     141
#                 ],
#                 [
#                     131,
#                     5,
#                     505
#                 ],
#                 [
#                     132,
#                     5,
#                     669
#                 ],
#                 [
#                     133,
#                     5,
#                     281
#                 ],
#                 [
#                     211,
#                     5,
#                     313
#                 ],
#                 [
#                     211,
#                     6,
#                     761
#                 ],
#                 [
#                     211,
#                     7,
#                     2
#                 ],
#                 [
#                     212,
#                     5,
#                     464
#                 ],
#                 [
#                     212,
#                     6,
#                     1233
#                 ],
#                 [
#                     212,
#                     7,
#                     8
#                 ],
#                 [
#                     213,
#                     5,
#                     37
#                 ],
#                 [
#                     213,
#                     6,
#                     163
#                 ],
#                 [
#                     221,
#                     5,
#                     376
#                 ],
#                 [
#                     221,
#                     6,
#                     951
#                 ],
#                 [
#                     222,
#                     5,
#                     522
#                 ],
#                 [
#                     222,
#                     6,
#                     1179
#                 ],
#                 [
#                     222,
#                     7,
#                     4
#                 ],
#                 [
#                     223,
#                     5,
#                     276
#                 ],
#                 [
#                     223,
#                     6,
#                     672
#                 ],
#                 [
#                     231,
#                     5,
#                     135
#                 ],
#                 [
#                     231,
#                     6,
#                     150
#                 ],
#                 [
#                     231,
#                     7,
#                     1
#                 ],
#                 [
#                     232,
#                     5,
#                     422
#                 ],
#                 [
#                     232,
#                     6,
#                     632
#                 ],
#                 [
#                     232,
#                     7,
#                     1
#                 ],
#                 [
#                     233,
#                     5,
#                     367
#                 ],
#                 [
#                     233,
#                     6,
#                     400
#                 ],
#                 [
#                     311,
#                     7,
#                     868
#                 ],
#                 [
#                     312,
#                     7,
#                     1092
#                 ],
#                 [
#                     313,
#                     7,
#                     231
#                 ],
#                 [
#                     321,
#                     7,
#                     678
#                 ],
#                 [
#                     322,
#                     7,
#                     743
#                 ],
#                 [
#                     323,
#                     7,
#                     605
#                 ],
#                 [
#                     331,
#                     7,
#                     84
#                 ],
#                 [
#                     332,
#                     7,
#                     243
#                 ],
#                 [
#                     333,
#                     7,
#                     89
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 1300,
#         "inRange": {
#             "color": [
#                 "#313695",
#                 "#4575b4",
#                 "#74add1",
#                 "#abd9e9",
#                 "#e0f3f8",
#                 "#ffffbf",
#                 "#fee090",
#                 "#fdae61",
#                 "#f46d43",
#                 "#d73027",
#                 "#a50026"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     },
#     "xAxis3D": {
#         "data": null,
#         "nameGap": 20,
#         "type": "category",
#         "axisLabel": {
#             "margin": 8
#         }
#     },
#     "yAxis3D": {
#         "data": null,
#         "nameGap": 20,
#         "type": "category",
#         "axisLabel": {
#             "margin": 8
#         }
#     },
#     "zAxis3D": {
#         "nameGap": 20,
#         "type": "value",
#         "axisLabel": {
#             "margin": 8
#         }
#     },
#     "grid3D": {
#         "boxWidth": 200,
#         "boxHeight": 100,
#         "boxDepth": 80,
#         "viewControl": {
#             "autoRotate": false,
#             "autoRotateSpeed": 10,
#             "rotateSensitivity": 1
#         }
#     },
#     "title": [
#         {
#             "text": "\u5065\u5eb7\u5e2eRFM\u4ef7\u503c\u5206\u5c42\u67f1\u72b63D\u56f

# %%
rfm_gb_

# %%
import pandas as pd
import matplotlib.pyplot as plt  # 导入图像库
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

# %%
data =  rfm_gb_[['rfm_score']]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
feature =data
K = range(2,10) # 设置主题个数区间
coef = []
for k in K:
    km = KMeans(n_clusters=k,random_state = 0).fit(feature) #构建kmeans模型并训练
    score = silhouette_score(feature, km.labels_,sample_size=1000) # 计算对应模型的轮廓系数
    coef.append(score)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(K,coef) # K为x轴输出，coef是y轴输出
plt.show()

# %%
# 确定k值
k = np.arange(1,11)
jarr = []
for i in k:
    model = KMeans(n_clusters=i)
    model.fit(data)
    jarr.append(model.inertia_)
    # 给这几个点打标
    plt.annotate(str(i),(i,model.inertia_))
plt.plot(k,jarr)
plt.show()
# # 经确定，k=4

# %%
k = 3

# %%
# 正式定义模型
model1 = KMeans(n_clusters=k)
# 跑模型
model1.fit(data)
# 需要知道每个类别有哪些参数
C_i = model1.predict(data)
# 还需要知道聚类中心的坐标
Muk = model1.cluster_centers_

# %%
Muk
# Out:
# array([[1.97322308],
#        [1.13013687],
#        [2.8687213 ]])
