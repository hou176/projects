# %%
import pandas as pd 
import numpy as np
import time

# %%
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv(r'D:\DTy_work\data\User_portrait_data\user_data.csv')
# Out:
# D:\anaconda0.1\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data=data[['id','省','加入时间']]

# %%
data = data.dropna(subset=['省'])

# %%
data
# Out:
#              id        省                        加入时间
# 0        757216      江苏省  2021-01-01 00:00:56.000000
# 1        757217      广东省  2021-01-01 00:01:00.000000
# 2        757218      北京市  2021-01-01 00:01:51.000000
# 3        757219  广西壮族自治区  2021-01-01 00:01:59.000000
# 4        757220      江西省  2021-01-01 00:03:35.000000
# ...         ...      ...                         ...
# 593781  1824872      广东省  2021-12-31 23:48:15.000000
# 593782  1824873      山西省  2021-12-31 23:49:48.000000
# 593784  1824875      浙江省  2021-12-31 23:53:22.000000
# 593785  1824876      重庆市  2021-12-31 23:53:25.000000
# 593786  1824877      广东省  2021-12-31 23:57:46.000000
#
# [519773 rows x 3 columns]

# %%
data['加入时间'] = pd.to_datetime(data['加入时间'])
# Out:
# C:\Users\cy176\AppData\Local\Temp/ipykernel_16144/3377952033.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['加入时间'] = pd.to_datetime(data['加入时间'])

# %%
data.dtypes
# Out:
# id               int64
# 省               object
# 加入时间    datetime64[ns]
# dtype: object

# %%
data['加入时间'] = pd.to_datetime(data['加入时间']).dt.date
# Out:
# C:\Users\cy176\AppData\Local\Temp/ipykernel_16144/472860782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['加入时间'] = pd.to_datetime(data['加入时间']).dt.date

# %%
data
# Out:
#              id        省        加入时间
# 0        757216      江苏省  2021-01-01
# 1        757217      广东省  2021-01-01
# 2        757218      北京市  2021-01-01
# 3        757219  广西壮族自治区  2021-01-01
# 4        757220      江西省  2021-01-01
# ...         ...      ...         ...
# 593781  1824872      广东省  2021-12-31
# 593782  1824873      山西省  2021-12-31
# 593784  1824875      浙江省  2021-12-31
# 593785  1824876      重庆市  2021-12-31
# 593786  1824877      广东省  2021-12-31
#
# [519773 rows x 3 columns]

# %%
df = pd.DataFrame({
    'key1':['a','a','b','b','a'],
    'key2':['one','two','one','two','one'],
    'data1':np.random.randn(5),
    'data2':np.random.randn(5)})

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -1.781742 -0.142923
# 1    a  two -1.729459  0.519993
# 2    b  one  0.979500  0.648181
# 3    b  two -1.174397  0.253984
# 4    a  one -0.119438  0.398364

# %%
datag =  data['省'].groupby([data['省'],data['加入时间']])

# %%
datag

# %%
datag = datag.count()

# %%
datag.to_csv(r'D:\DTy_work\data\User_portrait_data\datag1.csv')

# %%
datagg = pd.read_csv(r'D:\DTy_work\data\User_portrait_data\datag1.csv')

# %%
datagg
# Out:
#           省        加入时间  省.1
# 0       上海市  2021-01-01   32
# 1       上海市  2021-01-02   34
# 2       上海市  2021-01-03   38
# 3       上海市  2021-01-04   23
# 4       上海市  2021-01-05   38
# ...     ...         ...  ...
# 10376  黑龙江省  2021-12-27   30
# 10377  黑龙江省  2021-12-28   23
# 10378  黑龙江省  2021-12-29   26
# 10379  黑龙江省  2021-12-30   24
# 10380  黑龙江省  2021-12-31   19
#
# [10381 rows x 3 columns]

# %%
dataggd = datagg.drop_duplicates( subset = ['加入时间'],inplace = False)

# %%
dataggd = dataggd.sort_values(by='加入时间',ascending=True)

# %%
dataggd
# Out:
#        省        加入时间  省.1
# 0    上海市  2021-01-01   32
# 1    上海市  2021-01-02   34
# 2    上海市  2021-01-03   38
# 3    上海市  2021-01-04   23
# 4    上海市  2021-01-05   38
# ..   ...         ...  ...
# 332  上海市  2021-12-27   12
# 333  上海市  2021-12-28    6
# 334  上海市  2021-12-29    6
# 335  上海市  2021-12-30    8
# 336  上海市  2021-12-31    3
#
# [352 rows x 3 columns]

# %%
list1 =  list(dataggd['加入时间'])

# %%
dataframe = pd.DataFrame()
dataframe['省']= dataggd2[['省']]

# %%
dataggd
# Out:
#        省        加入时间  省.1
# 0    上海市  2021-01-01   32
# 1    上海市  2021-01-02   34
# 2    上海市  2021-01-03   38
# 3    上海市  2021-01-04   23
# 4    上海市  2021-01-05   38
# ..   ...         ...  ...
# 332  上海市  2021-12-27   12
# 333  上海市  2021-12-28    6
# 334  上海市  2021-12-29    6
# 335  上海市  2021-12-30    8
# 336  上海市  2021-12-31    3
#
# [352 rows x 3 columns]

# %%
dataframe = pd.DataFrame()
dataframe['省']= dataggd2[['省']]
dataframe['sum'] = 0
dataframe
# Out:
#               省  sum
# 0           上海市    0
# 337         云南省    0
# 684      内蒙古自治区    0
# 1032        北京市    0
# 1373        台湾省    0
# 1428        吉林省    0
# 1765        四川省    0
# 2115        天津市    0
# 2425    宁夏回族自治区    0
# 2714        安徽省    0
# 3059        山东省    0
# 3410        山西省    0
# 3753        广东省    0
# 4105    广西壮族自治区    0
# 4456   新疆维吾尔自治区    0
# 4767        江苏省    0
# 5117        江西省    0
# 5469        河北省    0
# 5817        河南省    0
# 6167        浙江省    0
# 6519        海南省    0
# 6848        湖北省    0
# 7196        湖南省    0
# 7546    澳门特别行政区    0
# 7609        甘肃省    0
# 7909        福建省    0
# 8257      西藏自治区    0
# 8335        贵州省    0
# 8676        辽宁省    0
# 9023        重庆市    0
# 9373        陕西省    0
# 9713        青海省    0
# 9905    香港特别行政区    0
# 10036      黑龙江省    0

# %%
kkk = pd.DataFrame()
kkk['省']= dataggd2[['省']]
for i in list1:
    dataframe=pd.merge(dataframe,datagg[datagg['加入时间'] == i][['省','省.1']].rename(columns={'省.1':i}),on='省',how =  'left')
    dataframe= dataframe.fillna(0)
    dataframe['sum'] = dataframe['sum'] + dataframe[i]
    dataframe = dataframe[['省','sum']]
    kkk = pd.merge(kkk,dataframe.rename(columns={'sum':i}),on='省',how =  'left')

# %%
kkk
# Out:
#            省  2021-01-01  2021-01-02  2021-01-03  2021-01-04  2021-01-05  \
# 0        上海市        32.0        66.0       104.0       127.0       165.0
# 1        云南省        48.0        99.0       193.0       270.0       346.0
# 2     内蒙古自治区        41.0        96.0       158.0       182.0       237.0
# 3        北京市        36.0        91.0       128.0       172.0       225.0
# 4        台湾省         0.0         0.0         0.0         1.0         2.0
# 5        吉林省        54.0       118.0       197.0       246.0       302.0
# 6        四川省        58.0       160.0       255.0       358.0       481.0
# 7        天津市        27.0        51.0        75.0        90.0       108.0
# 8    宁夏回族自治区        14.0        37.0        59.0        77.0        93.0
# 9        安徽省        52.0       105.0       223.0       323.0       403.0
# 10       山东省       168.0       361.0       546.0       779.0       960.0
# 11       山西省        27.0        91.0       131.0       174.0       221.0
# ...

# %%
kkk.to_csv(r'D:\DTy_work\data\User_portrait_data\kkk.csv')
